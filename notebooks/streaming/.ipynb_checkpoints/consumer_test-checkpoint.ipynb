# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import from_json, col
from pyspark.sql.types import StructType, StructField, DoubleType
from pyspark.ml.feature import VectorAssembler
import joblib
import numpy as np

# -------------------------
# 1️⃣ Spark session
# -------------------------
spark = SparkSession.builder \
    .appName("KafkaSparkXGB_CountFraud") \
    .getOrCreate()

spark.sparkContext.setLogLevel("ERROR")

# -------------------------
# 2️⃣ Schema
# -------------------------
schema = StructType(
    [StructField("Time", DoubleType(), True)] +
    [StructField(f"V{i}", DoubleType(), True) for i in range(1, 29)] +
    [StructField("Amount", DoubleType(), True)]
)

# -------------------------
# 3️⃣ Kafka stream
# -------------------------
kafka_df = spark.readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "localhost:9092") \
    .option("subscribe", "topic1") \
    .option("startingOffsets", "earliest") \
    .load()

# -------------------------
# 4️⃣ Parse JSON
# -------------------------
parsed_df = kafka_df.select(
    from_json(col("value").cast("string"), schema).alias("data")
).select("data.*")

# -------------------------
# 5️⃣ Feature Engineering
# -------------------------
feature_cols = ["Time"] + [f"V{i}" for i in range(1, 29)] + ["Amount"]
assembler = VectorAssembler(inputCols=feature_cols, outputCol="features")
features_df = assembler.transform(parsed_df)

# -------------------------
# 6️⃣ Load model
# -------------------------
xgb_model = joblib.load("../../models/xgboost_fraud_model2.pkl")

# -------------------------
# 7️⃣ Global counters
# -------------------------
total_seen = 0
total_predicted_fraud = 0

# -------------------------
# 8️⃣ Prediction + counting
# -------------------------
def predict_and_count(batch_df, batch_id):
    global total_seen, total_predicted_fraud

    batch_count = batch_df.count()
    if batch_count == 0:
        return

    pdf = batch_df.select("features").toPandas()
    X = np.array(pdf["features"].tolist())

    probas = xgb_model.predict_proba(X)[:, 1]

    # ⚠️ Choose threshold carefully
    predictions = (probas > 0.02).astype(int)

    batch_fraud = predictions.sum()

    total_seen += batch_count
    total_predicted_fraud += batch_fraud

    pdf["fraud_proba"] = probas
    pdf["prediction"] = predictions
    pdf["fraud"] = np.where(predictions == 1, "FRAUD", "")

    print("-------------------------------------------------------")

    print(f"\n========== BATCH {batch_id} ==========")

    print(pdf.head(5))

    print(f"Rows in batch: {batch_count}") # combien de transactions  dans le batch
    print(f"Fraud predicted in batch: {batch_fraud}") # fraud  dans le batch
    print(f"TOTAL rows seen: {total_seen}") # total transactions
    print(f"TOTAL fraud predicted: {total_predicted_fraud}") # total fraud 

    print("--------------------------------------------------------")

# -------------------------
# 9️⃣ Start stream
# -------------------------
query = features_df.writeStream \
    .foreachBatch(predict_and_count) \
    .trigger(processingTime="1 second") \
    .start()

query.awaitTermination()
# Out:
# 26/01/05 20:34:38 WARN Utils: Your hostname, DESKTOP-DD5N9SQ resolves to a loopback address: 127.0.1.1; using 172.17.138.117 instead (on interface eth0)
# 26/01/05 20:34:38 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/home/souhail/.local/lib/python3.10/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/souhail/.ivy2/cache
# The jars for the packages stored in: /home/souhail/.ivy2/jars
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-fdec2a87-9405-47cf-b1f7-2fab2dd66c0b;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.4.1 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.4.1 in central
# 	found org.apache.kafka#kafka-clients;3.3.2 in central
# 	found org.lz4#lz4-java;1.8.0 in central
# 	found org.xerial.snappy#snappy-java;1.1.10.1 in central
# 	found org.slf4j#slf4j-api;2.0.6 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.3.4 in central
# 	found org.apache.hadoop#hadoop-client-api;3.3.4 in central
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.apache.commons#commons-pool2;2.11.1 in central
# :: resolution report :: resolve 2722ms :: artifacts dl 75ms
# 	:: modules in use:
# 	com.google.code.findbugs#jsr305;3.0.0 from central in [default]
# 	commons-logging#commons-logging;1.1.3 from central in [default]
# 	org.apache.commons#commons-pool2;2.11.1 from central in [default]
# 	org.apache.hadoop#hadoop-client-api;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-client-runtime;3.3.4 from central in [default]
# 	org.apache.kafka#kafka-clients;3.3.2 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.12;3.4.1 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.4.1 from central in [default]
# 	org.lz4#lz4-java;1.8.0 from central in [default]
# 	org.slf4j#slf4j-api;2.0.6 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.10.1 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   11  |   0   |   0   |   0   ||   11  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-fdec2a87-9405-47cf-b1f7-2fab2dd66c0b
# 	confs: [default]
# 	0 artifacts copied, 11 already retrieved (0kB/30ms)
# 26/01/05 20:34:44 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# -------------------------------------------------------
#
# ========== BATCH 0 ==========
#                                             features  fraud_proba  prediction  \
# 0  [10.0, 1.249998742053, -1.22163680921816, 0.38...     0.000015           0
# 1  [23.0, 1.17328461017079, 0.353497876646456, 0....     0.000029           0
# 2  [25.0, 1.11400859541157, 0.0855460896870318, 0...     0.000110           0
# 3  [35.0, 1.38639697419213, -0.794209465382612, 0...     0.000038           0
# 4  [44.0, -0.7147640190509, 0.514968588809346, 1....     0.000034           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 375
# Fraud predicted in batch: 2
# TOTAL rows seen: 375
# TOTAL fraud predicted: 2
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 1 ==========
#                                             features  fraud_proba  prediction  \
# 0  [4989.0, 0.0830133938704318, -2.57575885144359...     0.000107           0
# 1  [5025.0, -0.72913915984776, 0.672145094328087,...     0.000168           0
# 2  [5087.0, 0.98922757582077, -0.593940959969546,...     0.000030           0
# 3  [5112.0, -1.84870708688827, 0.280349148660485,...     0.000012           0
# 4  [5149.0, -0.863246260928078, 1.53261752639294,...     0.000015           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 95
# Fraud predicted in batch: 1
# TOTAL rows seen: 470
# TOTAL fraud predicted: 3
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 2 ==========
#                                             features  fraud_proba  prediction  \
# 0  [7602.0, -4.51662576091355, 4.36639082838407, ...     0.008654           0
# 1  [7602.0, -4.51662576091355, 4.36639082838407, ...     0.008654           0
# 2  [7603.0, 1.11191901434011, 0.307953762638348, ...     0.000159           0
# 3  [7622.0, 1.37538902429059, -0.4462397302933, 0...     0.000033           0
# 4  [7660.0, -1.27862956327147, 0.138494440401919,...     0.000430           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 16
# Fraud predicted in batch: 1
# TOTAL rows seen: 486
# TOTAL fraud predicted: 4
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 3 ==========
#                                             features  fraud_proba  prediction  \
# 0  [7908.0, 1.17338163057742, 0.346744223333543, ...     0.000400           0
# 1  [7910.0, 1.18578229840366, 0.308527984368238, ...     0.000293           0
# 2  [7964.0, -1.17576498216189, 1.03849283075919, ...     0.000503           0
# 3  [7981.0, -0.167018648463641, 1.16737325131992,...     0.000736           0
# 4  [7991.0, 1.19763445374495, 0.309596690947662, ...     0.000465           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 12
# Fraud predicted in batch: 0
# TOTAL rows seen: 498
# TOTAL fraud predicted: 4
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 4 ==========
#                                             features  fraud_proba  prediction  \
# 0  [8231.0, -0.866956072796176, 0.520949168946539...     0.000426           0
# 1  [8258.0, -1.81207052950167, -0.215801729048684...     0.001509           0
# 2  [8292.0, 1.19995074606213, -0.174314684474059,...     0.000014           0
# 3  [8307.0, 0.967032204072339, -0.200890519052911...     0.000041           0
# 4  [8341.0, 1.17939766265314, -0.167090777910894,...     0.000020           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch:
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 36 ==========
#                                             features  fraud_proba  prediction  \
# 0  [19275.0, -2.50566402229315, 2.77454533853264,...     0.020804           1
# 1  [19299.0, -0.698567805157031, 0.22537131160386...     0.000018           0
# 2  [19302.0, 1.12820460401803, -0.400846483385731...     0.000024           0
# 3  [19377.0, -0.597826360862692, 1.31593475344872...     0.000159           0
# 4  [19432.0, 1.2844747535235, -0.528597383099064,...     0.000005           0
#
#    fraud
# 0  FRAUD
# 1
# 2
# 3
# 4
# Rows in batch: 12
# Fraud predicted in batch: 1
# TOTAL rows seen: 865
# TOTAL fraud predicted: 6
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 37 ==========
#                                             features  fraud_proba  prediction  \
# 0  [19692.0, 1.16588927982246, -0.390111726346565...     0.000022           0
# 1  [19703.0, 1.23192026331335, 0.844808503953946,...     0.034991           1
# 2  [19709.0, 1.12348925190108, 0.595106304898374,...     0.007728           0
# 3  [19756.0, 1.05651637994292, 0.190158721178656,...     0.000447           0
# 4  [19779.0, 1.24885541633418, 0.443627533210313,...     0.000083           0
#
#    fraud
# 0
# 1  FRAUD
# 2
# 3
# 4
# Rows in batch: 7
# Fraud predicted in batch: 1
# TOTAL rows seen: 872
# TOTAL fraud predicted: 7
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 38 ==========
#                                             features  fraud_proba  prediction  \
# 0  [19812.0, 1.18801585176914, -0.285960321401255...     0.000067           0
# 1  [19815.0, -0.663865209940577, 0.44422613300278...     0.000059           0
# 2  [19829.0, -1.26586066286382, 1.58793027219949,...     0.000033           0
# 3  [19848.0, 1.19408938142613, 0.322354954113888,...     0.000222           0
# 4  [19892.0, 1.37204624031322, -0.540021938829314...     0.000067           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 10
# Fraud predicted in batch: 0
# TOTAL rows seen: 882
# TOTAL fraud predicted: 7
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 39 ==========
#                                             features  fraud_proba  prediction  \
# 0  [19902.0, -0.724541931671757, 0.01134128162264...     0.000046           0
# 1  [19902.0, -0.191443939447219, -0.1620280613232...     0.000053           0
# 2  [19902.0, 1.4299746756055, -0.579305600751477,...     0.000019           0
# 3  [19903.0, 1.38698595754965, -0.421137361821887...     0.000027           0
# 4  [19904.0, 1.32957569240765, -0.523295821169465...     0.000063           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 9
# Fraud predicted in batch: 0
# TOTAL rows seen: 891
# TOTAL fraud predicted: 7
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 40 ==========
#                                             features  fraud_proba  prediction  \
# 0  [19909.0, 1.40144083198709, -0.603566281276216...     0.000056           0
# 1  [19910.0, 1.36344579034961, -0.460519569503079...     0.000041           0
# 2  [19911.0, 1.4444627472535, -0.595555479419308,...     0.000137           0
# 3  [19912.0, 0.0076659967914319, 0.15696195461968...     0.000161           0
# 4  [19912.0, 1.34896063968313, -0.42678453492407,...     0.000024           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 12
# Fraud predicted in batch: 0
# TOTAL rows seen: 903
# TOTAL fraud predicted: 7
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 41 ==========
#                                             features  fraud_proba  prediction  \
# 0  [19948.0, 1.08468044731481, 0.218005894748015,...     0.000128           0
# 1  [19963.0, 1.09687307137306, -0.438998102875523...     0.000024           0
# 2  [20004.0, -0.609279573171038, 0.32417004833411...     0.000028           0
# 3  [20060.0, -0.697505227657648, 0.42565612530505...     0.000023           0
# 4  [20062.0, -0.873645682385777, 0.05158908342735...     0.000245           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 7
# Fraud predicted in batch: 0
# TOTAL rows seen: 910
# TOTAL fraud predicted: 7
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 42 ==========
#                                             features  fraud_proba  prediction  \
# 0  [20099.0, -4.47501382965094, 3.73438691463578,...     0.000078           0
# 1  [20105.0, 1.10677335662669, 0.71233678370763, ...     0.087772           1
# 2  [20134.0, -3.83737348891213, 2.20015211491913,...     0.000007           0
# 3  [20191.0, 1.17133193480197, -0.352686248426648...     0.000065           0
# 4  [20281.0, 1.19802756654138, -0.264690564053454...     0.000092           0
#
#    fraud
# 0
# 1  FRAUD
# 2
# 3
# 4
# Rows in batch: 10
# Fraud predicted in batch: 1
# TOTAL rows seen: 920
# TOTAL fraud predicted: 8
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 43 ==========
#                                             features  fraud_proba  prediction  \
# 0  [20431.0, -0.672932647326822, 0.42645486163842...     0.000039           0
# 1  [20444.0, -0.374545873004156, 1.21122329295299...     0.000090           0
# 2  [20565.0, 1.10701027197602, 0.0261331173535247...     0.000236           0
# 3  [20594.0, 1.07574853824905, 0.0960636902711011...     0.000044           0
# 4  [20597.0, 1.17092776072297, -0.39261631157676,...     0.000067           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 8
# Fraud predicted in batch: 0
# TOTAL rows seen: 928
# TOTAL fraud predicted: 8
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 44 ==========
#                                             features  fraud_proba  prediction  \
# 0  [20691.0, 1.12734573410017, -0.48569786757972,...     0.000012           0
# 1  [20782.0, 0.937240439923766, -0.67640790378080...     0.000149           0
# 2  [20796.0, -0.723142247626097, 0.48427119863669...     0.000009           0
# 3  [20852.0, 1.01984885578317, -0.415504439398348...     0.000030           0
# 4  [20932.0, 1.27820579927311, -0.064602314084426...     0.000008           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 8
# Fraud predicted in batch: 0
# TOTAL rows seen: 936
# TOTAL fraud predicted: 8
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 45 ==========
#                                             features  fraud_proba  prediction  \
# 0  [21028.0, -1.63192207768891, 0.664863704905306...     0.000039           0
# 1  [21144.0, -0.21032653679781, -0.37016994187943...     0.000076           0
# 2  [21158.0, -0.0074027198649883, 0.2582076730285...     0.000017           0
# 3  [21193.0, 0.898614274555906, 0.033896192821782...     0.000486           0
# 4  [21194.0, 1.28100377452544, 0.175492105243575,...     0.000014           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 8
# Fraud predicted in batch: 1
# TOTAL rows seen: 944
# TOTAL fraud predicted: 9
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 46 ==========
#                                             features  fraud_proba  prediction  \
# 0  [21371.0, -8.29938102760656, 4.8235580435366, ...     0.000005           0
# 1  [21374.0, 1.01259468366088, 0.185411102837171,...     0.000319           0
# 2  [21396.0, 1.18691359574555, -0.251445628478105...     0.000035           0
# 3  [21400.0, -0.911605896060123, 0.93357757641069...     0.000687           0
# 4  [21429.0, -0.344769444875567, 1.06453650747292...     0.000158           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 11
# Fraud predicted in batch: 0
# TOTAL rows seen: 955
# TOTAL fraud predicted: 9
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 47 ==========
#                                             features  fraud_proba  prediction  \
# 0  [21621.0, 1.11758298577639, -0.718537107369355...     0.000077           0
# 1  [21636.0, 1.19099152133181, 0.203412465361523,...     0.000102           0
# 2  [21642.0, 1.25791311326245, -0.195039439152294...     0.000008           0
# 3  [21657.0, -0.646138237784299, 1.26798821085507...     0.000755           0
# 4  [21677.0, -0.88979337920413, 1.44199034270813,...     0.000453           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 9
# Fraud predicted in batch: 0
# TOTAL rows seen: 964
# TOTAL fraud predicted: 9
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 48 ==========
#                                             features  fraud_proba  prediction  \
# 0  [21800.0, 1.17691033262312, 0.0574361466908443...     0.000117           0
# 1  [21804.0, 1.04681746969126, -0.145300358080216...     0.000119           0
# 2  [21820.0, -1.29794559102018, 1.2814915675572, ...     0.000083           0
# 3  [21825.0, 1.27996187088846, -0.364425814905313...     0.000017           0
# 4  [21834.0, -0.645875884192146, 0.46205570486713...     0.000027           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 9
# Fraud predicted in batch: 1
# TOTAL rows seen: 973
# TOTAL fraud predicted: 10
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 49 ==========
#                                             features  fraud_proba  prediction  \
# 0  [21887.0, -0.694711782897451, 0.23468923319285...     0.000170           0
# 1  [21897.0, -0.185192320851207, 1.39845426948301...     0.001883           0
# 2  [21902.0, -0.922077273937383, 0.11502896871241...     0.000016           0
# 3  [21904.0, 0.94892358647049, -1.41574267562874,...     0.000161           0
# 4  [21917.0, 1.16614188862184, -0.365155436877745...     0.000012           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 9
# Fraud predicted in batch: 0
# TOTAL rows seen: 982
# TOTAL fraud predicted: 10
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 50 ==========
#                                             features  fraud_proba  prediction  \
# 0  [22026.0, 1.0186449736415, -0.663453500404094,...     0.000016           0
# 1  [22059.0, 1.10093782135434, 0.0737104110945799...     0.000107           0
# 2  [22068.0, -0.690832209859107, 0.42723869312415...     0.000016           0
# 3  [22080.0, -0.303293850636729, 1.44256593461713...     0.001373           0
# 4  [22080.0, 1.25110273037869, -0.387395906371516...     0.000202           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 8
# Fraud predicted in batch: 0
# TOTAL rows seen: 990
# TOTAL fraud predicted: 10
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 51 ==========
#                                             features  fraud_proba  prediction  \
# 0  [22200.0, 1.21823954756738, 0.898736088580802,...     0.000957           0
# 1  [22218.0, 1.26601140593678, -0.360136004168272...     0.000105           0
# 2  [22226.0, 1.17123089128222, -0.362668764214176...     0.000070           0
# 3  [22234.0, -0.91491252114199, -0.00137392863365...     0.000045           0
# 4  [22261.0, 1.0906656959063, 0.336108887850886, ...     0.000034           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 8
# Fraud predicted in batch: 0
# TOTAL rows seen: 998
# TOTAL fraud predicted: 10
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 52 ==========
#                                             features  fraud_proba  prediction  \
# 0  [22305.0, 1.04192548594858, -0.62649516366946,...     0.000034           0
# 1  [22321.0, 1.23558149777479, 0.576711826664102,...     0.001375           0
# 2  [22327.0, -0.949522403009005, 0.39587684158649...     0.000053           0
# 3  [22366.0, 1.23792511142463, 0.88001271570781, ...     0.030294           1
# 4  [22396.0, -0.864027572938705, 1.68001335062962...     0.000291           0
#
#    fraud
# 0
# 1
# 2
# 3  FRAUD
# 4
# Rows in batch: 9
# Fraud predicted in batch: 1
# TOTAL rows seen: 1007
# TOTAL fraud predicted: 11
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 1369 ==========
#                                             features  fraud_proba  prediction  \
# 0  [121800.0, 1.92902498545063, 0.626156817526338...     0.000654           0
# 1  [121801.0, 2.08096494979977, -0.05566038357301...     0.000076           0
# 2  [121804.0, 2.00030421550054, -0.69682237428652...     0.000049           0
# 3  [121811.0, -1.16961834236476, -1.9618811934714...     0.011896           0
# 4  [121833.0, -2.82256920304036, -1.9062062457877...     0.000282           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 8
# Fraud predicted in batch: 0
# TOTAL rows seen: 13696
# TOTAL fraud predicted: 147
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 1370 ==========
#                                             features  fraud_proba  prediction  \
# 0  [121846.0, 0.171884999421744, 1.16683232141553...     0.000180           0
# 1  [121848.0, -0.0340716807014346, 0.886550509004...     0.000049           0
# 2  [121851.0, -23.7610442653834, 4.91131358043017...     0.000004           0
# 3  [121851.0, 0.245741579672841, 0.89447728509776...     0.000212           0
# 4  [121859.0, 1.54535000483124, -0.60372209581239...     0.000194           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 9
# Fraud predicted in batch: 0
# TOTAL rows seen: 13705
# TOTAL fraud predicted: 147
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 1371 ==========
#                                             features  fraud_proba  prediction  \
# 0  [121867.0, 0.0365791165153162, 0.6885619284062...     0.016874           0
# 1  [121869.0, -1.70686832475584, 2.31875298045612...     0.000009           0
# 2  [121871.0, 2.02588508265289, -0.04107919743611...     0.000114           0
# 3  [121875.0, -1.40020447652606, 0.58980913954070...     0.000002           0
# 4  [121883.0, -0.0094825906896224, -0.13872667300...     0.000099           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 10
# Fraud predicted in batch: 0
# TOTAL rows seen: 13715
# TOTAL fraud predicted: 147
# --------------------------------------------------------
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/home/souhail/.local/lib/python3.10/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
# RuntimeError: reentrant call inside <_io.BufferedReader name=59>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/souhail/.local/lib/python3.10/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/home/souhail/.local/lib/python3.10/site-packages/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/home/souhail/.local/lib/python3.10/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/usr/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
#   File "/home/souhail/.local/lib/python3.10/site-packages/pyspark/context.py", line 377, in signal_handler
#     self.cancelAllJobs()
#   File "/home/souhail/.local/lib/python3.10/site-packages/pyspark/context.py", line 2255, in cancelAllJobs
#     self._jsc.sc().cancelAllJobs()
#   File "/home/souhail/.local/lib/python3.10/site-packages/py4j/java_gateway.py", line 1322, in __call__
#     return_value = get_return_value(
#   File "/home/souhail/.local/lib/python3.10/site-packages/pyspark/errors/exceptions/captured.py", line 169, in deco
#     return f(*a, **kw)
#   File "/home/souhail/.local/lib/python3.10/site-packages/py4j/protocol.py", line 334, in get_return_value
#     raise Py4JError(
# py4j.protocol.Py4JError: An error occurred while calling o16.sc
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/souhail/.local/lib/python3.10/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/home/souhail/.local/lib/python3.10/site-packages/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# -------------------------------------------------------
#
# ========== BATCH 1372 ==========
#                                             features  fraud_proba  prediction  \
# 0  [121936.0, 1.88913777015443, -0.10451833905614...     0.000129           0
# 1  [121938.0, 2.05834744648961, 0.073323538866932...     0.000155           0
# 2  [121943.0, 1.80707712543234, -0.98108265401240...     0.000088           0
# 3  [121963.0, -0.847440207548215, 0.0666811672163...     0.000023           0
# 4  [121970.0, 2.22730184837176, -0.73080165591498...     0.000047           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 12
# Fraud predicted in batch: 0
# TOTAL rows seen: 13727
# TOTAL fraud predicted: 147
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 1373 ==========
#                                             features  fraud_proba  prediction  \
# 0  [122001.0, 2.07443282609369, 0.068065678200447...     0.000017           0
# 1  [122008.0, -0.495839704299572, 1.2613328056675...     0.000069           0
# 2  [122010.0, -1.08289781644265, 1.13095167498329...     0.000032           0
# 3  [122014.0, 2.28861548867932, -1.44949072395732...     0.000312           0
# 4  [122016.0, 1.77764182514885, -0.29864934509448...     0.075651           1
#
#    fraud
# 0
# 1
# 2
# 3
# 4  FRAUD
# Rows in batch: 14
# Fraud predicted in batch: 1
# TOTAL rows seen: 13741
# TOTAL fraud predicted: 148
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 1374 ==========
#                                             features  fraud_proba  prediction  \
# 0  [122059.0, 2.23808094195388, -1.60909722520501...     0.000012           0
# 1  [122068.0, -0.657730432843179, 0.9799830769346...     0.000023           0
# 2  [122068.0, 2.17435656774858, -1.01249709685159...     0.000014           0
# 3  [122082.0, 2.12499510867588, -1.30386123283976...     0.000015           0
# 4  [122086.0, 2.3469899222005, -1.26160947144584,...     0.000023           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 7
# Fraud predicted in batch: 0
# TOTAL rows seen: 13748
# TOTAL fraud predicted: 148
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 1375 ==========
#                                             features  fraud_proba  prediction  \
# 0  [122121.0, -0.672811793602784, 1.5077189769881...     0.000014           0
# 1  [122125.0, -0.33358279682871, -0.8020282084885...     0.000238           0
# 2  [122126.0, 2.17048079492659, -0.50614234021827...     0.000149           0
# 3  [122132.0, -1.00375078636752, 0.51938409751226...     0.000006           0
# 4  [122133.0, -1.4110656717333, 0.146620522219334...     0.000040           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 6
# Fraud predicted in batch: 0
# TOTAL rows seen: 13754
# TOTAL fraud predicted: 148
# --------------------------------------------------------
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# Cell In[1], line 109
#     101 # -------------------------
#     102 # 9️⃣ Start stream
#     103 # -------------------------
#     104 query = features_df.writeStream \
#     105     .foreachBatch(predict_and_count) \
#     106     .trigger(processingTime="1 second") \
#     107     .start()
# --> 109 query.awaitTermination()
#
# File ~/.local/lib/python3.10/site-packages/pyspark/sql/streaming/query.py:201, in StreamingQuery.awaitTermination(self, timeout)
#     199     return self._jsq.awaitTermination(int(timeout * 1000))
#     200 else:
# --> 201     return self._jsq.awaitTermination()
#
# File ~/.local/lib/python3.10/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File ~/.local/lib/python3.10/site-packages/pyspark/errors/exceptions/captured.py:169, in capture_sql_exception.<locals>.deco(*a, **kw)
#     167 def deco(*a: Any, **kw: Any) -> Any:
#     168     try:
# --> 169         return f(*a, **kw)
#     170     except Py4JJavaError as e:
#     171         converted = convert_exception(e.java_exception)
#
# File ~/.local/lib/python3.10/site-packages/py4j/protocol.py:334, in get_return_value(answer, gateway_client, target_id, name)
#     330             raise Py4JError(
#     331                 "An error occurred while calling {0}{1}{2}. Trace:\n{3}\n".
#     332                 format(target_id, ".", name, value))
#     333     else:
# --> 334         raise Py4JError(
#     335             "An error occurred while calling {0}{1}{2}".
#     336             format(target_id, ".", name))
#     337 else:
#     338     type = answer[1]
#
# Py4JError: An error occurred while calling o67.awaitTermination
# -------------------------------------------------------
#
# ========== BATCH 1376 ==========
#                                             features  fraud_proba  prediction  \
# 0  [122139.0, -1.19752364326814, -0.0269463385528...     0.000061           0
# 1  [122150.0, -0.54530989968468, 2.21377812510744...     0.000171           0
# 2  [122150.0, 0.697563903796105, -2.6043306911539...     0.000160           0
# 3  [122153.0, 2.03499679478385, 0.273057863689555...     0.000245           0
# 4  [122156.0, 1.84860087316215, -0.64563032928484...     0.000195           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 28
# Fraud predicted in batch: 0
# TOTAL rows seen: 13782
# TOTAL fraud predicted: 148
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 1377 ==========
#                                             features  fraud_proba  prediction  \
# 0  [122253.0, -0.0759593964958621, -0.49054385070...     0.000305           0
# 1  [122256.0, 1.98961566801787, -0.32138317126297...     0.000119           0
# 2  [122258.0, -0.105421235312706, 1.0709081897529...     0.000289           0
# 3  [122259.0, -3.96994084051788, -3.7891503495484...     0.000174           0
# 4  [122266.0, -0.949190890990715, -0.949892884673...     0.000060           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 10
# Fraud predicted in batch: 0
# TOTAL rows seen: 13792
# TOTAL fraud predicted: 148
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 1378 ==========
#                                             features  fraud_proba  prediction  \
# 0  [122306.0, -0.114792740897675, 0.9418614669201...     0.000059           0
# 1  [122307.0, 1.9383321248534, 0.0607512539026117...     0.000092           0
# 2  [122308.0, 2.0167159911193, -0.071790275849549...     0.000196           0
# 3  [122314.0, -4.40802278858029, -6.2114595063155...     0.000048           0
# 4  [122319.0, -0.10744574644968, 1.06723810373538...     0.000918           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 6
# Fraud predicted in batch: 0
# TOTAL rows seen: 13798
# TOTAL fraud predicted: 148
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 1379 ==========
#                                             features  fraud_proba  prediction  \
# 0  [122323.0, 2.05947999557988, -0.08484154482624...     0.000027           0
# 1  [122331.0, -0.267001970469934, 0.2100527998795...     0.000051           0
# 2  [122336.0, 2.02805256707945, -0.62288049529112...     0.000096           0
# 3  [122343.0, -0.0658420003557438, 1.782551222574...     0.000216           0
# 4  [122348.0, -0.660361022113825, 1.2162625156803...     0.003153           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 5
# Fraud predicted in batch: 0
# TOTAL rows seen: 13803
# TOTAL fraud predicted: 148
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 1380 ==========
#                                             features  fraud_proba  prediction  \
# 0  [122357.0, -4.76062352775201, 4.43244902876528...     0.000005           0
# 1  [122357.0, 2.09699454197037, 0.177829859395343...     0.000725           0
# 2  [122377.0, -0.824474463708777, 0.6801907758792...     0.003404           0
# 3  [122382.0, -0.989893860910085, -1.455921451013...     0.000042           0
# 4  [122385.0, 0.088927408352427, 0.75491198032227...     0.000043           0
#
#   fraud
# 0
# 1
# 2
# 3
# 4
# Rows in batch: 10
# Fraud predicted in batch: 0
# TOTAL rows seen: 13813
# TOTAL fraud predicted: 148
# --------------------------------------------------------
# -------------------------------------------------------
#
# ========== BATCH 1381 ==========
#                                             features  fraud_proba  prediction  \
# 0  [122429.0, 0.338270036652785, -0.6603663524949...     0.000018           0
# 1  [122431.0, 0.0905709704411862, 0.9297215471431...     0.000008           0
#
#   fraud
# 0
# 1
# Rows in batch: 2
# Fraud predicted in batch: 0
# TOTAL rows seen: 13815
# TOTAL fraud predicted: 148
# --------------------------------------------------------
